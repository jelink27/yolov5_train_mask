# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
 
import torch

print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14661, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 14661 (delta 1), reused 4 (delta 1), pack-reused 14654
# Receiving objects: 100% (14661/14661), 13.79 MiB | 17.39 MiB/s, done.
# Resolving deltas: 100% (10091/10091), done.
# /content/yolov5
#      |████████████████████████████████| 182 kB 30.3 MB/s
#      |████████████████████████████████| 62 kB 706 kB/s
#      |████████████████████████████████| 1.6 MB 29.2 MB/s
# Setup complete. Using torch 1.13.0+cu116 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/yolo/data #list檢查檔案在不在
# Out:
# Apple_Orange.zip  convert_annotations.py  FaceMaskDataset.zip
# classes.txt	  datadownloadv5.ipynb	  test.mp4

# %%
# copy over the dataset into the root directory of the Colab VM (comment out test.zip if you are not using a validation dataset)

# !cp /content/drive/MyDrive/yolo/data/FaceMaskDataset.zip /content

# %%
# unzip the dataset and the contents so that they are now in /content folder

# !unzip /content/FaceMaskDataset.zip -d /content/ #copy過來後unzip
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: /content/FaceMaskDataset/images/val/4558.jpg
#   inflating: /content/FaceMaskDataset/images/val/4559.jpg
#   inflating: /content/FaceMaskDataset/images/val/4560.jpg
#   inflating: /content/FaceMaskDataset/images/val/4561.jpg
#   inflating: /content/FaceMaskDataset/images/val/4562.jpg
#   inflating: /content/FaceMaskDataset/images/val/4563.jpg
#   inflating: /content/FaceMaskDataset/images/val/4564.jpg
#   inflating: /content/FaceMaskDataset/images/val/4565.jpg
#   inflating: /content/FaceMaskDataset/images/val/4566.jpg
#   inflating: /content/FaceMaskDataset/images/val/4567.jpg
#   inflating: /content/FaceMaskDataset/images/val/4568.jpg
#   inflating: /content/FaceMaskDataset/images/val/4569.jpg
#   inflating: /content/FaceMaskDataset/images/val/4570.jpg
#   inflating: /content/FaceMaskDataset/images/val/4571.jpg
#   inflating: /content/FaceMaskDataset/images/val/4572.jpg
#   inflating: /content/FaceMaskDataset/images/val/4573.jpg
# ...

# %%
# https://github.com/ultralytics/yolov5/wiki/Train-Custom-Data

#!python train.py --img 512 --batch 16 --epochs 10 --hyp /content/drive/MyDrive/yolo/yolov5/hyp.custom.yaml  --data /content/drive/MyDrive/yolo/yolov5/plate.yaml  --weights yolov5x.pt --name ''
# !python train.py --img 256 --batch 32 --epochs 10 --hyp /content/drive/MyDrive/yolo/yolov5/hyp.custom.yaml  --data /content/drive/MyDrive/yolo/yolov5/mask.yaml  --weights yolov5x.pt --name ''#權重用yolov5x x是最大型 小一點可以用n or s or l
# Out:
# train: weights=yolov5x.pt, cfg=, data=/content/drive/MyDrive/yolo/yolov5/mask.yaml, hyp=/content/drive/MyDrive/yolo/yolov5/hyp.custom.yaml, epochs=10, batch_size=32, imgsz=256, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-198-gacff977 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
## To save model weights to your google drive!

# !cp 'runs/train2/weights/best.pt' /content/drive/MyDrive/yolo/yolov5/

# %%
## check training metrics: /content/yolov5/runs/train/results.png

# %%
# YOLOv5 PyTorch Hub inference: https://github.com/ultralytics/yolov5/issues/36
# Inference with detect.py
# condf 0.25 sigmoid輸出定義0.25以上就是true
# !python detect.py --weights runs/train2/weights/best.pt --img 256 --conf 0.25 --source '/content/drive/MyDrive/yolo/yolov5/mask.jpg'
#也可以新增IoU --IoU 預設0.45 預設跟真實交集的框框
# Out:
# detect: weights=['runs/train2/weights/best.pt'], source=/content/drive/MyDrive/yolo/yolov5/mask.jpg, data=data/coco128.yaml, imgsz=[256, 256], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-198-gacff977 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 322 layers, 86180143 parameters, 0 gradients, 203.8 GFLOPs
# image 1/1 /content/drive/MyDrive/yolo/yolov5/mask.jpg: 160x256 5 face masks, 28.1ms
# Speed: 0.3ms pre-process, 28.1ms inference, 1.6ms NMS per image at shape (1, 3, 256, 256)
# Results saved to runs/detect/exp4

# %%
# local video path or youtube video link

# !python detect.py --weights runs/train2/weights/best.pt --source '/content/drive/MyDrive/yolo/data/videoplayback.mp4'
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# video 1/1 (131/5128) /content/drive/MyDrive/yolo/data/videoplayback.mp4: 384x640 4 face masks, 34.0ms
# video 1/1 (132/5128) /content/drive/MyDrive/yolo/data/videoplayback.mp4: 384x640 4 face masks, 33.3ms
# video 1/1 (133/5128) /content/drive/MyDrive/yolo/data/videoplayback.mp4: 384x640 4 face masks, 34.0ms
# video 1/1 (134/5128) /content/drive/MyDrive/yolo/data/videoplayback.mp4: 384x640 4 face masks, 33.6ms
# video 1/1 (135/5128) /content/drive/MyDrive/yolo/data/videoplayback.mp4: 384x640 4 face masks, 32.9ms
# video 1/1 (136/5128) /content/drive/MyDrive/yolo/data/videoplayback.mp4: 384x640 4 face masks, 33.8ms
# video 1/1 (137/5128) /content/drive/MyDrive/yolo/data/videoplayback.mp4: 384x640 4 face masks, 34.0ms
# video 1/1 (138/5128) /content/drive/MyDrive/yolo/data/videoplayback.mp4: 384x640 4 face masks, 34.0ms
# video 1/1 (139/5128) /content/drive/MyDrive/yolo/data/videoplayback.mp4: 384x640 4 face masks, 33.9ms
# ...

# %%
# local video path or youtube video link

# !python detect.py --weights runs/train/weights/best.pt --source '/content/drive/MyDrive/yolo/data/test.mp4'
# Out:
# detect: weights=['runs/train/weights/best.pt'], source=/content/drive/MyDrive/yolo/data/test.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-162-g55fbac9 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# YOLOv5x summary: 362 layers, 88390614 parameters, 0 gradients
# video 1/1 (1/1805) /content/drive/MyDrive/yolo/data/test.mp4: 384x640 (no detections), 27.2ms
# video 1/1 (2/1805) /content/drive/MyDrive/yolo/data/test.mp4: 384x640 (no detections), 27.0ms
# video 1/1 (3/1805) /content/drive/MyDrive/yolo/data/test.mp4: 384x640 (no detections), 26.9ms
# ...

# %%
# !cp /content/yolov5/runs/detect/exp2/test.mp4 /content/drive/MyDrive/yolo/yolov5/
